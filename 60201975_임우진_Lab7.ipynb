# %%
import pandas as pd
import seaborn as sns
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# 문제 3번
# o = planets[planets['year'] == 2011].groupby(['year', 'method'])['distance'].mean()
# o
l = planets.groupby(['year', 'method'])['distance'].mean()
l.loc[2011]
# Out:
# method
# Eclipse Timing Variations                NaN
# Imaging                            21.150000
# Microlensing                             NaN
# Orbital Brightness Modulation    1180.000000
# Pulsar Timing                    1200.000000
# Radial Velocity                    58.762688
# Transit                           683.233929
# Transit Timing Variations        2119.000000
# Name: distance, dtype: float64

# %% [markdown]
# ## 한눈에 파악하기 어려우며 NaN 값이 많음을 볼 수 있음.

# %%
# 문제 2번
import pandas as pd
pd.pivot_table(planets, index = ['year'],columns = ['method'], values = ['orbital_period'], aggfunc= "mean")
# Out:
#        orbital_period                                                        \
# method     Astrometry Eclipse Timing Variations        Imaging Microlensing
# year
# 1989              NaN                       NaN            NaN          NaN
# 1992              NaN                       NaN            NaN          NaN
# 1994              NaN                       NaN            NaN          NaN
# 1995              NaN                       NaN            NaN          NaN
# 1996              NaN                       NaN            NaN          NaN
# 1997              NaN                       NaN            NaN          NaN
# 1998              NaN                       NaN            NaN          NaN
# 1999              NaN                       NaN            NaN          NaN
# 2000              NaN                       NaN            NaN          NaN
# 2001              NaN                       NaN            NaN          NaN
# ...

# %% [markdown]
# ## Radial Velocity, Transit, Imaging 각각 순서대로 많이 집계 되었음을 볼 수 있습니다. 이외의 행성 발견 방법 또한 집계되나 큰 의미가 있지 않음을 볼 수 있습니다.

# %%
# 문제 1번
planets.groupby(['method'])['number'].count().plot.bar(rot = 90)
# Out:
# <Axes: xlabel='method'>

# %%
# 문제 4번
import matplotlib.pyplot as plt
l = planets.groupby(['year', 'method'])['distance'].mean().unstack()
plt.figure(figsize=(15, 7))
sns.heatmap(l, cmap = 'Blues', annot=True, fmt=".0f")
# Out:
# <Axes: xlabel='method', ylabel='year'>
